# %% [markdown]
# # Crawling tutorial
#
# A web scraper script is anlogous to a spider that crawls a website's graph of URLs.
# In this tutorial, we'll look at some examples of Python libraries for downloading and undestanding website stucture.
#
# For optimal viewing of this notebook, you should enable the custom "wide format":
# `cat wide_notebooks.css >> ../../venv/lib/python3.X/site-packages/notebook/static/custom/custom.css` (replace X with 4/5/6 depending on your version of Python)

# %%
import json
from basiccrawler.crawler import BasicCrawler

crawler = BasicCrawler(
        main_source_domain='http://chef-take-home-test.learningequality.org',
        start_page='http://chef-take-home-test.learningequality.org/')
crawler.CRAWLING_STAGE_OUTPUT = 'chefdata/trees/takehome_web_resource_tree.json'

channel_tree = crawler.crawl(limit=1000)
crawler.print_tree(channel_tree, print_depth=1)
# Out:
# ################################################################################
# # CRAWLER RECOMMENDATIONS BASED ON URLS ENCOUNTERED:
# ################################################################################
#
# 1. These URLs are very common and look like global navigation links:
#
# 2. These are common path fragments found in URLs paths, so could correspond to site struture:
#   -  7 urls on site start with  /Math
#   -  7 urls on site start with  /Science
#   -  1 urls on site start with  /
#
#
# ################################################################################
#
#
#
#   - path: /  (PageWebResource)
#     children:
#      - path: /Math/  (PageWebResource)
#        children counts: {'PageWebResource': 6}
#      - path: /Science/  (PageWebResource)
#        children counts: {'PageWebResource': 6}

# %%
crawler.print_tree(channel_tree, print_depth=2)
# Out:
#   - path: /  (PageWebResource)
#     children:
#      - path: /Math/  (PageWebResource)
#        children:
#         - path: /Math/Numbers/  (PageWebResource)
#           children counts: {'PageWebResource': 2}
#         - path: /Math/Functions/  (PageWebResource)
#           children counts: {'PageWebResource': 1}
#         - path: /Math/Vectors_overview/  (PageWebResource)
#      - path: /Science/  (PageWebResource)
#        children:
#         - path: /Science/Biology/  (PageWebResource)
#           children counts: {'PageWebResource': 1}
#         - path: /Science/Chemistry/  (PageWebResource)
#           children counts: {'PageWebResource': 1}
#         - path: /Science/Physics/  (PageWebResource)
#           children counts: {'PageWebResource': 1}

# %%
print(json.dumps(channel_tree, indent =2))
# Out:
# {
#   "kind": "PageWebResource",
#   "url": "http://chef-take-home-test.learningequality.org/",
#   "children": [
#     {
#       "kind": "PageWebResource",
#       "url": "http://chef-take-home-test.learningequality.org/Math/",
#       "children": [
#         {
#           "kind": "PageWebResource",
#           "url": "http://chef-take-home-test.learningequality.org/Math/Numbers/",
#           "children": [
#             {
#               "kind": "PageWebResource",
#               "url": "http://chef-take-home-test.learningequality.org/Math/Numbers/Numbers_Overview/",
#               "children": []
#             },
#             {
#               "kind": "PageWebResource",
#               "url": "http://chef-take-home-test.learningequality.org/Math/Numbers/Classifying_numbers/",
#               "children": []
#             }
#           ]
#         },
#         {
#           "kind": "PageWebResource",
#           "url": "http://chef-take-home-test.learningequality.org/Math/Functions/",
#           "children": [
#             {
#               "kind": "PageWebResource",
#               "url": "http://chef-take-home-test.learningequality.org/Math/Functions/Functions_overview/",
#               "children": []
#             }
#           ]
#         },
#         {
#           "kind": "PageWebResource",
#           "url": "http://chef-take-home-test.learningequality.org/Math/Vectors_overview/",
#           "children": []
#         }
#       ]
#     },
#     {
#       "kind": "PageWebResource",
#       "url": "http://chef-take-home-test.learningequality.org/Science/",
#       "children": [
#         {
#           "kind": "PageWebResource",
#           "url": "http://chef-take-home-test.learningequality.org/Science/Biology/",
#           "children": [
#             {
#               "kind": "PageWebResource",
#               "url": "http://chef-take-home-test.learningequality.org/Science/Biology/Whale_sounds/",
#               "children": []
#             }
#           ]
#         },
#         {
#           "kind": "PageWebResource",
#           "url": "http://chef-take-home-test.learningequality.org/Science/Chemistry/",
#           "children": [
#             {
#               "kind": "PageWebResource",
#               "url": "http://chef-take-home-test.learningequality.org/Science/Chemistry/Organic_chemistry/",
#               "children": []
#             }
#           ]
#         },
#         {
#           "kind": "PageWebResource",
#           "url": "http://chef-take-home-test.learningequality.org/Science/Physics/",
#           "children": [
#             {
#               "kind": "PageWebResource",
#               "url": "http://chef-take-home-test.learningequality.org/Science/Physics/Wave_particle_duality/",
#               "children": []
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }

# %%
from basiccrawler.crawler import BasicCrawler

skills_crawler = BasicCrawler(
        main_source_domain='https://applieddigitalskills.withgoogle.com',
        start_page='https://applieddigitalskills.withgoogle.com/en/curriculum')
skills_crawler.CRAWLING_STAGE_OUTPUT = 'chefdata/trees/skills_web_resource_tree.json'

# undomment below
skills_channel_tree = skills_crawler.crawl(limit=100)
# skills_crawler.print_tree(skills_channel_tree, print_depth=2)
# Out:
# Starting new HTTPS connection (1): applieddigitalskills.withgoogle.com
# https://applieddigitalskills.withgoogle.com:443 "HEAD /en/curriculum HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/en/curriculum title:Curriculum - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/en/curriculum
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /apps HTTP/1.1" 302 0
# https://applieddigitalskills.withgoogle.com:443 "HEAD /en/apps HTTP/1.1" 200 0
# https://applieddigitalskills.withgoogle.com:443 "GET /apps HTTP/1.1" 302 0
# Downloaded page https://applieddigitalskills.withgoogle.com/apps title:Free Technology Curriculum from Google - Applied Digital Skills
# in on_page https://applieddigitalskills.withgoogle.com/en/apps
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /high-school HTTP/1.1" 302 0
# https://applieddigitalskills.withgoogle.com:443 "HEAD /en/high-school HTTP/1.1" 200 0
# https://applieddigitalskills.withgoogle.com:443 "GET /high-school HTTP/1.1" 302 0
# Downloaded page https://applieddigitalskills.withgoogle.com/high-school title:Learn Digital Skills to Solve Everyday Tasks - Applied Digital Skills
# in on_page https://applieddigitalskills.withgoogle.com/en/high-school
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /adults HTTP/1.1" 302 0
# https://applieddigitalskills.withgoogle.com:443 "HEAD /en/adults HTTP/1.1" 200 0
# https://applieddigitalskills.withgoogle.com:443 "GET /adults HTTP/1.1" 302 0
# Downloaded page https://applieddigitalskills.withgoogle.com/adults title:Grow Your Career with Applied Digital Skills - Applied Digital Skills
# in on_page https://applieddigitalskills.withgoogle.com/en/adults
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /educators HTTP/1.1" 302 0
# https://applieddigitalskills.withgoogle.com:443 "HEAD /en/educators HTTP/1.1" 200 0
# https://applieddigitalskills.withgoogle.com:443 "GET /educators HTTP/1.1" 302 0
# Downloaded page https://applieddigitalskills.withgoogle.com/educators title:Digital Tools to Help Learners Succeed Online - Applied Digital Skills
# in on_page https://applieddigitalskills.withgoogle.com/en/educators
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /curriculum HTTP/1.1" 302 0
# https://applieddigitalskills.withgoogle.com:443 "HEAD /en/curriculum HTTP/1.1" 200 0
# https://applieddigitalskills.withgoogle.com:443 "GET /curriculum HTTP/1.1" 302 0
# Downloaded page https://applieddigitalskills.withgoogle.com/curriculum title:Curriculum - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/en/curriculum
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /apps/route HTTP/1.1" 302 0
# https://applieddigitalskills.withgoogle.com:443 "HEAD /hybridauth/window/Google?destination=apps/role&destination_error=apps/role HTTP/1.1" 302 0
# https://applieddigitalskills.withgoogle.com:443 "HEAD /hybridauth/endpoint?hauth.start=Google&hauth.time=1511672631 HTTP/1.1" 302 0
# Starting new HTTPS connection (1): accounts.google.com
# https://accounts.google.com:443 "HEAD /o/oauth2/auth?client_id=697756715164-tg5ir0ti7hocn6mbb5m390n3d6gqoskc.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fapplieddigitalskills.withgoogle.com%2Fhybridauth%2Fendpoint%3Fhauth.done%3DGoogle&response_type=code&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.profile+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&access_type=online&prompt=select_account&hl=en HTTP/1.1" 302 0
# https://accounts.google.com:443 "HEAD /ServiceLogin?passive=1209600&continue=https://accounts.google.com/o/oauth2/auth?client_id%3D697756715164-tg5ir0ti7hocn6mbb5m390n3d6gqoskc.apps.googleusercontent.com%26redirect_uri%3Dhttps://applieddigitalskills.withgoogle.com/hybridauth/endpoint?hauth.done%253DGoogle%26response_type%3Dcode%26scope%3Dhttps://www.googleapis.com/auth/userinfo.profile%2Bhttps://www.googleapis.com/auth/userinfo.email%26access_type%3Donline%26prompt%3Dselect_account%26hl%3Den%26from_login%3D1%26as%3D327d64101a0d1455&hl=en&oauth=1&sarp=1&scc=1 HTTP/1.1" 200 0
# https://applieddigitalskills.withgoogle.com:443 "GET /apps/route HTTP/1.1" 302 0
# https://applieddigitalskills.withgoogle.com:443 "GET /hybridauth/window/Google?destination=apps/role&destination_error=apps/role HTTP/1.1" 302 0
# https://applieddigitalskills.withgoogle.com:443 "GET /hybridauth/endpoint?hauth.start=Google&hauth.time=1511672632 HTTP/1.1" 302 0
# https://accounts.google.com:443 "GET /o/oauth2/auth?client_id=697756715164-tg5ir0ti7hocn6mbb5m390n3d6gqoskc.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fapplieddigitalskills.withgoogle.com%2Fhybridauth%2Fendpoint%3Fhauth.done%3DGoogle&response_type=code&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.profile+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&access_type=online&prompt=select_account&hl=en HTTP/1.1" 302 0
# https://accounts.google.com:443 "GET /ServiceLogin?passive=1209600&continue=https://accounts.google.com/o/oauth2/auth?client_id%3D697756715164-tg5ir0ti7hocn6mbb5m390n3d6gqoskc.apps.googleusercontent.com%26redirect_uri%3Dhttps://applieddigitalskills.withgoogle.com/hybridauth/endpoint?hauth.done%253DGoogle%26response_type%3Dcode%26scope%3Dhttps://www.googleapis.com/auth/userinfo.profile%2Bhttps://www.googleapis.com/auth/userinfo.email%26access_type%3Donline%26prompt%3Dselect_account%26hl%3Den%26from_login%3D1%26as%3D-351fe9e05fe0beb0&hl=en&oauth=1&sarp=1&scc=1 HTTP/1.1" 200 None
# Downloaded page https://applieddigitalskills.withgoogle.com/apps/route title:Sign in - Google Accounts
# in on_page https://accounts.google.com/ServiceLogin?passive=1209600&continue=https://accounts.google.com/o/oauth2/auth?client_id%3D697756715164-tg5ir0ti7hocn6mbb5m390n3d6gqoskc.apps.googleusercontent.com%26redirect_uri%3Dhttps://applieddigitalskills.withgoogle.com/hybridauth/endpoint?hauth.done%253DGoogle%26response_type%3Dcode%26scope%3Dhttps://www.googleapis.com/auth/userinfo.profile%2Bhttps://www.googleapis.com/auth/userinfo.email%26access_type%3Donline%26prompt%3Dselect_account%26hl%3Den%26from_login%3D1%26as%3D-351fe9e05fe0beb0&hl=en&oauth=1&sarp=1&scc=1
# https://applieddigitalskills.withgoogle.com:443 "HEAD /user/logout?destination=/apps HTTP/1.1" 403 0
# ERROR 403 when getting url=https://applieddigitalskills.withgoogle.com/user/logout?destination=/apps
# HEAD request failed for url https://applieddigitalskills.withgoogle.com/user/logout?destination=/apps
# HEAD https://applieddigitalskills.withgoogle.com/user/logout?destination=/apps did not return response.
# Starting new HTTPS connection (2): applieddigitalskills.withgoogle.com
# https://applieddigitalskills.withgoogle.com:443 "HEAD /apps/dashboard HTTP/1.1" 403 0
# ERROR 403 when getting url=https://applieddigitalskills.withgoogle.com/apps/dashboard
# HEAD request failed for url https://applieddigitalskills.withgoogle.com/apps/dashboard
# HEAD https://applieddigitalskills.withgoogle.com/apps/dashboard did not return response.
# Starting new HTTPS connection (3): applieddigitalskills.withgoogle.com
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/overview.html title:If-Then Adventure Stories - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/overview.html title:Research and Develop a Topic - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/technology-ethics-and-security/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/technology-ethics-and-security/overview.html title:Technology, Ethics, and Security - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/technology-ethics-and-security/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/plan-an-event/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/overview.html title:Plan an Event — Middle and High School - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/guide-to-an-area/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/guide-to-an-area/overview.html title:Guide to an Area - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/guide-to-an-area/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/technologys-role-in-current-events/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/technologys-role-in-current-events/overview.html title:Technology's Role in Current Events - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/technologys-role-in-current-events/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/plan-and-budget/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-and-budget/overview.html title:Plan and Budget - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-and-budget/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/create-an-editing-tool-with-programming/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/create-an-editing-tool-with-programming/overview.html title:Create an Editing Tool with Programming - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/create-an-editing-tool-with-programming/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/technology-at-work/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/technology-at-work/overview.html title:Technology at Work - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/technology-at-work/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/pick-the-next-box-office-hit/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/pick-the-next-box-office-hit/overview.html title:Pick the Next Box Office Hit - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/pick-the-next-box-office-hit/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/equal-access-to-technology/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/equal-access-to-technology/overview.html title:Equal Access to Technology - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/equal-access-to-technology/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/plan-an-event-college-and-continuing-education/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event-college-and-continuing-education/overview.html title:Plan an Event — College and Continuing Education - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event-college-and-continuing-education/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/plan-and-budget-college-and-continuing-education/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-and-budget-college-and-continuing-education/overview.html title:Plan and Budget - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-and-budget-college-and-continuing-education/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/use-google-to-get-a-new-job-college-and-continuing-education/overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/use-google-to-get-a-new-job-college-and-continuing-education/overview.html title:Use Google to Get a New Job - Applied Digital Skills from Google
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/use-google-to-get-a-new-job-college-and-continuing-education/overview.html
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /footer HTTP/1.1" 301 0
# Starting new HTTPS connection (1): google.com
# https://google.com:443 "HEAD /grow HTTP/1.1" 301 0
# Starting new HTTPS connection (1): www.google.com
# https://www.google.com:443 "HEAD /grow HTTP/1.1" 301 0
# Starting new HTTPS connection (1): grow.google
# https://grow.google:443 "HEAD / HTTP/1.1" 200 0
# https://google.com:443 "GET /grow HTTP/1.1" 301 224
# https://www.google.com:443 "GET /grow HTTP/1.1" 301 217
# https://grow.google:443 "GET / HTTP/1.1" 200 13476
# Downloaded page https://applieddigitalskills.withgoogle.com/footer title:Grow with Google - Learn Digital Skills, Prepare for Jobs, Grow Your Business
# in on_page https://grow.google/
# https://applieddigitalskills.withgoogle.com:443 "HEAD /en/apps HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/en/apps title:Free Technology Curriculum from Google - Applied Digital Skills
# in on_page https://applieddigitalskills.withgoogle.com/en/apps
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /en/high-school HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/en/high-school title:Learn Digital Skills to Solve Everyday Tasks - Applied Digital Skills
# in on_page https://applieddigitalskills.withgoogle.com/en/high-school
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/if-then-adventure-stories-introduction.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/if-then-adventure-stories-introduction.html title:If-Then Adventure Stories Introduction
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/if-then-adventure-stories-introduction.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/unit-introduction.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/unit-introduction.html title:Unit Introduction
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/unit-introduction.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/plan-an-event/select-and-research-an-event/unit-introduction.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/select-and-research-an-event/unit-introduction.html title:Unit Introduction
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/select-and-research-an-event/unit-introduction.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/guide-to-an-area/create-an-area-guide/organize-data-to-create-an-area-guide.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/guide-to-an-area/create-an-area-guide/organize-data-to-create-an-area-guide.html title:Organize Data to Create an Area Guide
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/guide-to-an-area/create-an-area-guide/organize-data-to-create-an-area-guide.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/plan-and-budget/make-a-long-term-spending-decision/budget-to-make-good-financial-decisions.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-and-budget/make-a-long-term-spending-decision/budget-to-make-good-financial-decisions.html title:Budget to Make Good Financial Decisions
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-and-budget/make-a-long-term-spending-decision/budget-to-make-good-financial-decisions.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/create-an-editing-tool-with-programming/identify-programming-concepts-in-everyday-life/using-programming-to-automate-tasks.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/create-an-editing-tool-with-programming/identify-programming-concepts-in-everyday-life/using-programming-to-automate-tasks.html title:Using Programming to Automate Tasks
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/create-an-editing-tool-with-programming/identify-programming-concepts-in-everyday-life/using-programming-to-automate-tasks.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/pick-the-next-box-office-hit/review-movie-ideas/pick-the-next-box-office-hit-intro.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/pick-the-next-box-office-hit/review-movie-ideas/pick-the-next-box-office-hit-intro.html title:Pick the Next Box Office Hit Intro
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/pick-the-next-box-office-hit/review-movie-ideas/pick-the-next-box-office-hit-intro.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /en/adults HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/en/adults title:Grow Your Career with Applied Digital Skills - Applied Digital Skills
# in on_page https://applieddigitalskills.withgoogle.com/en/adults
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/plan-an-event-college-and-continuing-education/course-introduction/course-introduction.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event-college-and-continuing-education/course-introduction/course-introduction.html title:Course Introduction
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event-college-and-continuing-education/course-introduction/course-introduction.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/plan-and-budget-college-and-continuing-education/make-a-long-term-spending-decision/budget-to-make-good-financial-decisions.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-and-budget-college-and-continuing-education/make-a-long-term-spending-decision/budget-to-make-good-financial-decisions.html title:Budget to Make Good Financial Decisions
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-and-budget-college-and-continuing-education/make-a-long-term-spending-decision/budget-to-make-good-financial-decisions.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/use-google-to-get-a-new-job-college-and-continuing-education/use-google-to-get-a-new-job--unit-introduction/use-google-to-get-a-new-job--unit-introduction.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/use-google-to-get-a-new-job-college-and-continuing-education/use-google-to-get-a-new-job--unit-introduction/use-google-to-get-a-new-job--unit-introduction.html title:Use Google to Get a New Job - Unit Introduction
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/use-google-to-get-a-new-job-college-and-continuing-education/use-google-to-get-a-new-job--unit-introduction/use-google-to-get-a-new-job--unit-introduction.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /en/educators HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/en/educators title:Digital Tools to Help Learners Succeed Online - Applied Digital Skills
# in on_page https://applieddigitalskills.withgoogle.com/en/educators
# a with no nohref found <a class="mdl-navigation__link openmenu">Menu <i class="material-icons">keyboard_arrow_down</i></a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/introduction-to-applied-digital-skills/google-apps-overview.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/introduction-to-applied-digital-skills/google-apps-overview.html title:Google Apps Overview
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/introduction-to-applied-digital-skills/google-apps-overview.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/introduction-to-applied-digital-skills/google-apps-pre-survey.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/introduction-to-applied-digital-skills/google-apps-pre-survey.html title:Google Apps Pre-Survey
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/introduction-to-applied-digital-skills/google-apps-pre-survey.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/introduction-to-group-decision-making.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/introduction-to-group-decision-making.html title:Introduction to Group Decision Making
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/introduction-to-group-decision-making.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/brainstorm-story-elements.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/brainstorm-story-elements.html title:Brainstorm Story Elements
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/brainstorm-story-elements.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/wrap-up.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/wrap-up.html title:Wrap Up
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/wrap-up.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/introduction-to-ifthen-adventure-stories.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/introduction-to-ifthen-adventure-stories.html title:Introduction to If/Then Adventure Stories
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/introduction-to-ifthen-adventure-stories.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/set-up-your-first-slides.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/set-up-your-first-slides.html title:Set Up Your First Slides
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/set-up-your-first-slides.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/create-choices-and-links.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/create-choices-and-links.html title:Create Choices and Links
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/create-choices-and-links.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/connect-and-create.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/connect-and-create.html title:Connect and Create
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/connect-and-create.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/reflection.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/reflection.html title:Reflection
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/reflection.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/wrap-up/unit-wrap.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/wrap-up/unit-wrap.html title:Unit Wrap
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/wrap-up/unit-wrap.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/wrap-up/if-then-adventure-stories-reflection.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/wrap-up/if-then-adventure-stories-reflection.html title:If-Then Adventure Stories Reflection
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/wrap-up/if-then-adventure-stories-reflection.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/if-then-adventure-stories/wrap-up/if-then-adventure-stories-extensions.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/wrap-up/if-then-adventure-stories-extensions.html title:If-Then Adventure Stories Extensions
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/wrap-up/if-then-adventure-stories-extensions.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/credibility-clues.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/credibility-clues.html title:Credibility Clues
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/credibility-clues.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/select-a-topic-and-write-your-fake-article.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/select-a-topic-and-write-your-fake-article.html title:Select a Topic and Write Your Fake Article
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/select-a-topic-and-write-your-fake-article.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/share-and-evaluate-articles.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/share-and-evaluate-articles.html title:Share and Evaluate Articles
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/share-and-evaluate-articles.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/wrap-up-credibility-checks.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/wrap-up-credibility-checks.html title:Wrap-Up Credibility Checks
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/wrap-up-credibility-checks.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/reflection.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/reflection.html title:Reflection
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/reflection.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/choose-a-research-topic.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/choose-a-research-topic.html title:Choose a Research Topic
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/choose-a-research-topic.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/search-the-internet-for-information.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/search-the-internet-for-information.html title:Search the Internet for Information
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/search-the-internet-for-information.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/record-your-research-notes.html HTTP/1.1" 200 0
# Downloaded page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/record-your-research-notes.html title:Record Your Research Notes
# in on_page https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/record-your-research-notes.html
# a with no nohref found <a class="mdl-navigation__link curriculum-nav">
#
#             Curriculum
#
#             <i class="material-icons-extended">keyboard_arrow_down</i>
# </a>
# a with no nohref found <a class="mobile-instructions subheader" id="back-to-units">
# <i class="material-icons-extended">navigate_before</i>
#
#       Back to Units
#
#     </a>
# https://applieddigitalskills.withgoogle.com:443 "HEAD /applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/write-a-paragraph-about-your-topic.html HTTP/1.1" 200 0
# ...
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/plan-tasks-for-your-event/activity-reflection-for-plan-tasks-for-you-event.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/introduction-to-event-communication.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/create-a-shared-calendar.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/schedule-meetings-and-events.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/add-an-event-email-signature.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/email-your-team.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/wrap-up-event-communication.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/reflection.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/introduction-to-logos.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/add-and-edit-images.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/add-and-format-text.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/advanced-options-in-google-drawings.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/logo-wrap-up.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/activity-reflection-for-create-a-logo.htmladding to global_nav_nodes
# Found candidate for global nav url=https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/build-a-flyer-to-advertise/introduction-to-flyers.htmladding to global_nav_nodes
# ################################################################################
# # CRAWLER RECOMMENDATIONS BASED ON URLS ENCOUNTERED:
# ################################################################################
#
# 1. These URLs are very common and look like global navigation links:
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/if-then-adventure-stories-introduction.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/unit-introduction.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/select-and-research-an-event/unit-introduction.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/guide-to-an-area/create-an-area-guide/organize-data-to-create-an-area-guide.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-and-budget/make-a-long-term-spending-decision/budget-to-make-good-financial-decisions.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/create-an-editing-tool-with-programming/identify-programming-concepts-in-everyday-life/using-programming-to-automate-tasks.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/pick-the-next-box-office-hit/review-movie-ideas/pick-the-next-box-office-hit-intro.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event-college-and-continuing-education/course-introduction/course-introduction.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-and-budget-college-and-continuing-education/make-a-long-term-spending-decision/budget-to-make-good-financial-decisions.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/use-google-to-get-a-new-job-college-and-continuing-education/use-google-to-get-a-new-job--unit-introduction/use-google-to-get-a-new-job--unit-introduction.html
#   -  https://applieddigitalskills.withgoogle.com/user/logout?destination=/apps
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/introduction-to-applied-digital-skills/google-apps-overview.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/introduction-to-applied-digital-skills/google-apps-pre-survey.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/introduction-to-group-decision-making.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/brainstorm-story-elements.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/brainstorm-story-ideas/wrap-up.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/introduction-to-ifthen-adventure-stories.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/set-up-your-first-slides.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/create-choices-and-links.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/connect-and-create.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/create-an-ifthen-adventure/reflection.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/wrap-up/unit-wrap.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/wrap-up/if-then-adventure-stories-reflection.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/if-then-adventure-stories/wrap-up/if-then-adventure-stories-extensions.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/credibility-clues.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/select-a-topic-and-write-your-fake-article.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/share-and-evaluate-articles.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/wrap-up-credibility-checks.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/test-for-credibility/reflection.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/choose-a-research-topic.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/search-the-internet-for-information.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/record-your-research-notes.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/write-a-paragraph-about-your-topic.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/wrap-up-researching-a-topic.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/explore-a-topic-with-research-and-collaboration/reflection.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/code-welcome-screen/introduction-to-coding.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/code-welcome-screen/explore-the-script-editor.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/code-welcome-screen/create-an-alert.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/code-welcome-screen/add-visual-appeal-to-your-popup.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/code-welcome-screen/show-an-html-formatted-message.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/code-welcome-screen/make-the-pop-up-open-automatically.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/code-welcome-screen/reflection.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/wrap-up/unit-wrap.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/wrap-up/research-and-develop-a-topic-reflection.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/research-and-develop-a-topic/wrap-up/research-and-develop-a-topic-extensions.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/technology-ethics-and-security/technology-ethics-and-security/explore-create-communicate-introduction.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/technology-ethics-and-security/technology-ethics-and-security/introduction-to-the-topics.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/technology-ethics-and-security/technology-ethics-and-security/explore-technology-ethics-and-security.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/technology-ethics-and-security/technology-ethics-and-security/technology-ethics-and-security-reflection.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/select-and-research-an-event/choose-an-event.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/select-and-research-an-event/event-questions-and-research.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/select-and-research-an-event/give-and-receive-feedback.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/select-and-research-an-event/organize-your-event-plan.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/select-and-research-an-event/wrap-up-event-selection.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/select-and-research-an-event/activity-reflection-for-select-and-research-an-event.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/plan-tasks-for-your-event/introduction-to-spreadsheets.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/plan-tasks-for-your-event/understand-spreadsheet-vocabulary.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/plan-tasks-for-your-event/add-items-to-your-spreadsheet.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/plan-tasks-for-your-event/add-columns-for-task-owners.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/plan-tasks-for-your-event/complete-task-list-and-get-feedback.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/plan-tasks-for-your-event/wrap-up-to-do-list.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/plan-tasks-for-your-event/activity-reflection-for-plan-tasks-for-you-event.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/introduction-to-event-communication.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/create-a-shared-calendar.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/schedule-meetings-and-events.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/add-an-event-email-signature.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/email-your-team.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/wrap-up-event-communication.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/communicate-with-gmail-and-calendar/reflection.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/introduction-to-logos.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/add-and-edit-images.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/add-and-format-text.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/advanced-options-in-google-drawings.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/logo-wrap-up.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/create-a-logo/activity-reflection-for-create-a-logo.html
#   -  https://applieddigitalskills.withgoogle.com/applied-digital-skills/en/plan-an-event/build-a-flyer-to-advertise/introduction-to-flyers.html
#
# 2. These are common path fragments found in URLs paths, so could correspond to site struture:
#   -  89 urls on site start with  /applied-digital-skills
#   -  5 urls on site start with  /en
#   -  2 urls on site start with  /
#   -  1 urls on site start with  /user
#   -  1 urls on site start with  /apps
#
# 3. These are broken links --- you might want to add them to IGNORE_URLS
# ['https://applieddigitalskills.withgoogle.com/user/logout?destination=/apps', 'https://applieddigitalskills.withgoogle.com/apps/dashboard']
#
#
# ################################################################################

# %%
# le_crawler.print_tree(le_channel_tree, print_depth=5)

# %%
# le_crawler.infer_tree_structure(le_channel_tree)

# %%
import re
from crawler import BasicCrawler

ict_crawler = BasicCrawler(
        main_source_domain='https://ict-essentials-for-teachers.moodlecloud.com',
        start_page='https://ict-essentials-for-teachers.moodlecloud.com/')
ict_crawler.IGNORE_URL_PATTERNS.append(re.compile('.*[\?&]lang=.*'))
ict_crawler.IGNORE_URL_PATTERNS.append(re.compile('.*calendar/set\.php.*'))
ict_crawler.IGNORE_URL_PATTERNS.append(re.compile('.*calendar/view\.php.*'))


# ict_channel_tree = ict_crawler.crawl(limit=1000)

# %%
# ict_crawler.print_tree(ict_channel_tree, print_depth=2)

# %%
# ict_crawler.infer_tree_structure(ict_channel_tree)

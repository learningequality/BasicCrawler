# %%
from basiccrawler.crawler import BasicCrawler

# %%
crawler = BasicCrawler(main_source_domain='http://tahriracademy.org',
                       start_page='http://tahriracademy.org/')
crawler.CRAWLING_STAGE_OUTPUT = 'chefdata/trees/tahrir_web_resource_tree.json'

channel_tree = crawler.crawl(limit=10000)
# Out:
# Downloaded page http://tahriracademy.org/ title:أكاديمية التحرير
# in on_page http://tahriracademy.org/
# Downloaded page http://tahriracademy.org/connect/facebook?_destination=http%3A//tahriracademy.org/connect/finish_login title:Facebook
# in on_page https://www.facebook.com/login.php?skip_api_login=1&api_key=737357366291128&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv2.5%2Fdialog%2Foauth%3Fredirect_uri%3Dhttp%253A%252F%252Ftahriracademy.org%252Fsocial%252Ffacebook%26display%3Dpopup%26scope%3Demail%2B%2Buser_birthday%2Buser_friends%26response_type%3Dcode%26client_id%3D737357366291128%26ret%3Dlogin%26logger_id%3D14d3062b-b4ef-23ff-9ef3-6e1a7aeab4ef&cancel_url=http%3A%2F%2Ftahriracademy.org%2Fsocial%2Ffacebook%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%23_%3D_&display=popup&locale=en_US&logger_id=14d3062b-b4ef-23ff-9ef3-6e1a7aeab4ef
# ...

# %%
crawler.print_tree(channel_tree, print_depth=3)
# Out:
#      - path: /  (PageWebResource)
#        children:
#         - path: https://www.facebook.com/login.php?skip_api_login=1&api_key=737357366291128&signed_next=1&next=https%3A%2F%2Fwww.facebook.com%2Fv2.5%2Fdialog%2Foauth%3Fredirect_uri%3Dhttp%253A%252F%252Ftahriracademy.org%252Fsocial%252Ffacebook%26display%3Dpopup%26scope%3Demail%2B%2Buser_birthday%2Buser_friends%26response_type%3Dcode%26client_id%3D737357366291128%26ret%3Dlogin%26logger_id%3D14d3062b-b4ef-23ff-9ef3-6e1a7aeab4ef&cancel_url=http%3A%2F%2Ftahriracademy.org%2Fsocial%2Ffacebook%3Ferror%3Daccess_denied%26error_code%3D200%26error_description%3DPermissions%2Berror%26error_reason%3Duser_denied%23_%3D_&display=popup&locale=en_US&logger_id=14d3062b-b4ef-23ff-9ef3-6e1a7aeab4ef  (PageWebResource)
#         - path: /category/70/%D8%A3%D9%88%D9%84%D9%89-%D8%A7%D8%B9%D8%AF%D8%A7%D8%AF%D9%89  (PageWebResource)
#           children:
# ...
